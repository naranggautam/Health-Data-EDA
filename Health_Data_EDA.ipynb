# %%
#import the required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('health data eda.csv')

#Excel: pd.read_excel
#Text: pd.read_csv sep: ' ' ',' ';' ':'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 0      2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1      5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2      4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3      8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4      8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...             ...            ...    ...                   ...
# 97109  7.499459e+12        5738090      F  2016-05-25T10:28:45Z
# 97110  1.263472e+13        5578722      F  2016-04-13T13:25:22Z
# 97111  5.682146e+13        5432647      M  2016-03-04T14:15:30Z
# 97112  1.966893e+14        5534241      F  2016-03-31T15:35:14Z
# 97113  1.371925e+13        5444861      M  2016-03-08T16:42:19Z
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      2016-04-29T00:00:00Z   62    JARDIM DA PENHA          0.0
# ...

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA          0.0           1.0
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA          0.0           0.0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA          0.0           0.0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI          0.0           0.0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA          0.0           1.0
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0       0.0         0.0      0.0           0.0      No
# ...

# %%
df.shape
# Out:
# (97114, 14)

# %%
df.columns.values
# Out:
# array(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship',
#        'Hipertension', 'Diabetes', 'Alcoholism', 'Handcap',
#        'SMS_received', 'No-show'], dtype=object)

# %%
df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
##changing names of columns
df=df.rename(columns={'Hipertension': 'Hypertension', 'Handcap' : 'Handicap', 'SMS_received' : 'SMSReceived','No-show' : 'NoShow' })

# %%
df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hypertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMSReceived', 'NoShow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97114 entries, 0 to 97113
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientId       97114 non-null  float64
#  1   AppointmentID   97114 non-null  int64
#  2   Gender          97114 non-null  object
#  3   ScheduledDay    97114 non-null  object
#  4   AppointmentDay  97114 non-null  object
#  5   Age             97114 non-null  int64
#  6   Neighbourhood   97114 non-null  object
#  7   Scholarship     97113 non-null  float64
#  8   Hypertension    97113 non-null  float64
#  9   Diabetes        97113 non-null  float64
#  10  Alcoholism      97113 non-null  float64
#  11  Handicap        97113 non-null  float64
#  12  SMSReceived     97113 non-null  float64
#  13  NoShow          97113 non-null  object
# dtypes: float64(7), int64(2), object(5)
# memory usage: 10.4+ MB

# %%
# Checking the data types of all the columns
df.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship       float64
# Hypertension      float64
# Diabetes          float64
# Alcoholism        float64
# Handicap          float64
# SMSReceived       float64
# NoShow             object
# dtype: object

# %%
##modifying date and time into standard form
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay']).dt.date.astype('datetime64[ns]')
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay']).dt.date.astype('datetime64[ns]')

# %%
df.head(5)
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA          0.0           1.0       0.0         0.0
# 1    JARDIM DA PENHA          0.0           0.0       0.0         0.0
# 2      MATA DA PRAIA          0.0           0.0       0.0         0.0
# 3  PONTAL DE CAMBURI          0.0           0.0       0.0         0.0
# 4    JARDIM DA PENHA          0.0           1.0       1.0         0.0
#
#    Handicap  SMSReceived NoShow
# 0       0.0          0.0     No
# 1       0.0          0.0     No
# ...

# %%
## 5 is saturday, 6 is sunday

df['sch_weekday'] = df['ScheduledDay'].dt.dayofweek

# %%
df['app_weekday'] = df['AppointmentDay'].dt.dayofweek

# %%
df['sch_weekday'].value_counts()
# Out:
# 1    23551
# 2    20905
# 0    20056
# 4    16794
# 3    15785
# 5       23
# Name: sch_weekday, dtype: int64

# %%
df['app_weekday'].value_counts()
# Out:
# 1    23342
# 2    21274
# 0    20401
# 4    16999
# 3    15059
# 5       39
# Name: app_weekday, dtype: int64

# %%
# Check the descriptive statistics of numeric variables
df.describe()
# Out:
#           PatientId  AppointmentID           Age   Scholarship  Hypertension  \
# count  9.711400e+04   9.711400e+04  97114.000000  97113.000000  97113.000000
# mean   1.471689e+14   5.667012e+06     37.112455      0.098617      0.197708
# std    2.557889e+14   6.894174e+04     23.158119      0.298149      0.398273
# min    9.377953e+04   5.030230e+06      0.000000      0.000000      0.000000
# 25%    4.169785e+12   5.636412e+06     18.000000      0.000000      0.000000
# 50%    3.172104e+13   5.673436e+06     37.000000      0.000000      0.000000
# 75%    9.437955e+13   5.713033e+06     56.000000      0.000000      0.000000
# max    9.999816e+14   5.790484e+06    115.000000      1.000000      1.000000
#
#            Diabetes    Alcoholism      Handicap   SMSReceived   sch_weekday  \
# count  97113.000000  97113.000000  97113.000000  97113.000000  97114.000000
# mean       0.072308      0.029224      0.022170      0.303924      1.853564
# ...

# %%
##dropping some columns which have no significance

df.drop(['PatientId', 'AppointmentID', 'Neighbourhood'], axis=1, inplace=True)

# %%
df
# Out:
#       Gender ScheduledDay AppointmentDay  Age  Scholarship  Hypertension  \
# 0          F   2016-04-29     2016-04-29   62          0.0           1.0
# 1          M   2016-04-29     2016-04-29   56          0.0           0.0
# 2          F   2016-04-29     2016-04-29   62          0.0           0.0
# 3          F   2016-04-29     2016-04-29    8          0.0           0.0
# 4          F   2016-04-29     2016-04-29   56          0.0           1.0
# ...      ...          ...            ...  ...          ...           ...
# 97109      F   2016-05-25     2016-06-02   77          0.0           0.0
# 97110      F   2016-04-13     2016-06-02   79          0.0           1.0
# 97111      M   2016-03-04     2016-06-02   85          0.0           1.0
# 97112      F   2016-03-31     2016-06-02   80          0.0           0.0
# 97113      M   2016-03-08     2016-06-02   69          NaN           NaN
#
#        Diabetes  Alcoholism  Handicap  SMSReceived NoShow  sch_weekday  \
# ...

# %%
df['NoShow'].value_counts().plot(kind='barh', figsize=(8,6))
plt.xlabel("Count", labelpad = 14)
plt.ylabel("Target Variable", labelpad = 14)
plt.title("Count of TARGET Variable per category", y=1.02);

# %%
## calculating the % of appointments or not
100*df['NoShow'].value_counts()/len(df['NoShow'])
# Out:
# No     79.726919
# Yes    20.272051
# Name: NoShow, dtype: float64

# %%
df['NoShow'].value_counts()
# Out:
# No     77426
# Yes    19687
# Name: NoShow, dtype: int64

# %%
## Having a look that data contains missing value or not
# Create a DataFrame to calculate missing value percentages
missing = pd.DataFrame((df.isnull().sum()) * 100 / df.shape[0]).reset_index()

# Create the plot
plt.figure(figsize=(16, 5))
ax = sns.pointplot(x='index', y=0, data=missing)  # Use 'x' and 'y' for the column names
plt.xticks(rotation=90, fontsize=7)
plt.title("Percentage of Missing Values")
plt.ylabel("PERCENTAGE")
plt.xlabel("Features")  # Added this line to label the x-axis
plt.show()

# %% [markdown]
# **Missing Data - Initial Intuition**
#
# We don't have any missing data
#
# **General Thumb Rules**
#
# For features with less missing values - can use regression to predict the missing value to fill with the mean of the value present, depending on the feature.
#
# For feature with very high number of missing values, it is better to drop those columns as they give very less insight on analysis.
#
# As there is no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delet the columns, if you have 30-40% of missing values.

# %% [markdown]
# **Data Cleaning**
#
# Create a copy of base data for manipulation and processing

# %%
new_data=df.copy()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97114 entries, 0 to 97113
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          97114 non-null  object
#  1   ScheduledDay    97114 non-null  datetime64[ns]
#  2   AppointmentDay  97114 non-null  datetime64[ns]
#  3   Age             97114 non-null  int64
#  4   Scholarship     97113 non-null  float64
#  5   Hypertension    97113 non-null  float64
#  6   Diabetes        97113 non-null  float64
#  7   Alcoholism      97113 non-null  float64
#  8   Handicap        97113 non-null  float64
#  9   SMSReceived     97113 non-null  float64
#  10  NoShow          97113 non-null  object
#  11  sch_weekday     97114 non-null  int64
#  12  app_weekday     97114 non-null  int64
# dtypes: datetime64[ns](2), float64(6), int64(3), object(2)
# memory usage: 9.6+ MB

# %% [markdown]
# As we don't have any null values, there is no data cleaning required.

# %%
## Get the max tenure
print(df['Age'].max())
# Out:
# 115

# %%
## Group the Tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i+20) for i in range(1, 118, 20)]
df['Age_group'] = pd.cut(df.Age, range(1,130,20), right=False, labels=labels)
df.drop(['Age'], axis=1, inplace=True)

# %% [markdown]
# **Data Exploration**

# %%
list(df.columns)
# Out:
# ['Gender',
#  'ScheduledDay',
#  'AppointmentDay',
#  'Scholarship',
#  'Hypertension',
#  'Diabetes',
#  'Alcoholism',
#  'Handicap',
#  'SMSReceived',
#  'NoShow',
#  'sch_weekday',
#  'app_weekday',
#  'Age_group']

# %%
# Having a look into values of count of each columns their count in respect to NoShow column
for i, predictor in enumerate(df.drop(columns= ['NoShow'])):
  print('-'*10, predictor, '-'*10)
  print(df[predictor].value_counts())
  plt.figure(i)
  sns.countplot(data=df, x=predictor, hue='NoShow')
# Out:
# ---------- Gender ----------
# F    63176
# M    33938
# Name: Gender, dtype: int64
# ---------- ScheduledDay ----------
# 2016-05-02    4142
# 2016-05-03    4068
# 2016-05-05    3901
# 2016-05-10    3866
# 2016-05-09    3809
#               ...
# 2015-12-03       1
# 2016-04-16       1
# 2016-01-28       1
# 2015-11-10       1
# 2016-06-04       1
# Name: ScheduledDay, Length: 107, dtype: int64
# ---------- AppointmentDay ----------
# 2016-05-16    4613
# 2016-05-09    4520
# 2016-05-30    4514
# 2016-05-11    4474
# 2016-05-12    4394
# 2016-05-02    4376
# 2016-05-18    4373
# 2016-05-17    4372
# 2016-05-10    4308
# 2016-05-31    4279
# 2016-05-05    4273
# 2016-05-19    4270
# 2016-05-03    4256
# 2016-05-04    4168
# 2016-05-24    4009
# 2016-05-13    3987
# 2016-05-25    3909
# 2016-05-06    3879
# 2016-05-20    3828
# 2016-04-29    3235
# 2016-06-06    2378
# 2016-06-08    2206
# 2016-06-01    2144
# 2016-06-02    2122
# 2016-06-07    2118
# 2016-06-03    2070
# ...

# %%
df['NoShow'] = np.where(df.NoShow == 'Yes', 1, 0)
df.NoShow.value_counts()
# Out:
# 0    77427
# 1    19687
# Name: NoShow, dtype: int64

# %% [markdown]
# Convert all the categorical varibales into dummy variables

# %%
df_dummies = pd.get_dummies(df)
df_dummies.head()
# Out:
#   ScheduledDay AppointmentDay  Scholarship  Hypertension  Diabetes  \
# 0   2016-04-29     2016-04-29          0.0           1.0       0.0
# 1   2016-04-29     2016-04-29          0.0           0.0       0.0
# 2   2016-04-29     2016-04-29          0.0           0.0       0.0
# 3   2016-04-29     2016-04-29          0.0           0.0       0.0
# 4   2016-04-29     2016-04-29          0.0           1.0       1.0
#
#    Alcoholism  Handicap  SMSReceived  NoShow  sch_weekday  app_weekday  \
# 0         0.0       0.0          0.0       0            4            4
# 1         0.0       0.0          0.0       0            4            4
# 2         0.0       0.0          0.0       0            4            4
# 3         0.0       0.0          0.0       0            4            4
# 4         0.0       0.0          0.0       0            4            4
#
#    Gender_F  Gender_M  Age_group_1 - 21  Age_group_21 - 41  Age_group_41 - 61  \
# ...

# %% [markdown]
# Build a correlationof all predictors with 'NoShow'

# %%
plt.figure(figsize=(20,8))
df_dummies.corr()['NoShow'].sort_values(ascending = False, ).plot(kind = 'bar')
# Out:
# <ipython-input-42-99c7e8cd76bf>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_dummies.corr()['NoShow'].sort_values(ascending = False, ).plot(kind = 'bar')
# <Axes: >

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df_dummies.corr(),cmap='Paired')
# Out:
# <ipython-input-43-c02f4a486087>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_dummies.corr(),cmap='Paired')
# <Axes: >

# %% [markdown]
# **Bivariate Analysis**

# %%
new_df1_target0=df.loc[df["NoShow"]==0]

# %%
new_df1_target1=df.loc[df["NoShow"]==1]

# %%
def uniplot(df,col,title,hue =None):

    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30


    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright')

    plt.show()

# %%
uniplot(new_df1_target1,col='Hypertension',title='Distribution of Gender for NoShow Customers',hue='Gender')

# %%
uniplot(new_df1_target0,col='Hypertension',title='Distribution of Gender for NoShow Customers',hue='Gender')

# %%
uniplot(new_df1_target1,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')

# %%
uniplot(new_df1_target0,col='Age_group',title='Distribution of Age for NoShow Customers',hue='Gender')

# %% [markdown]
# **Findings**
# Female patients have taken more appointments then male patients
# Ratio of Nohow and Show is almost equal for age group except Age 0 and Age 1 with 80% show rate for each age group
#
# Each Neighbourhood have almost 80% show rate
#
# There are 99666 patients without Scholarship and out of them around 80% have come for the visit and out of the 21801 patients with Scholarship around 75% of them have come for the visit.
#
# there are around 88,726 patients without Hypertension and out of them around 78% have come for the visit and Out of the 21801 patients with Hypertension around 85% of them have come for the visit.
#
# there are around 102,584 patients without Diabetes and out of them around 80% have come for the visit and Out of the 7,943 patients with Diabetes around 83% of them have come for the visit.
#
# there are around 75,045 patients who have not received SMS and out of them around 84% have come for the visit and out of the 35,482 patients who have received SMS around 72% of them have come for the visit.
#
# there is no appointments on sunday and on saturday appointments are very less in comparision to other week days
